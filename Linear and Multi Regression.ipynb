# %% [markdown]
# #### check the version of pandas

# %%
import pandas
pandas.__version__
# Out:
# '1.0.5'

# %% [markdown]
# #### file path check by using pwd(work directory cammond) copy the data file in it.

# %%
pwd
# Out:
# 'C:\\Users\\sandi'

# %% [markdown]
# #### import all libabries that are required

# %%
import numpy as np
import pandas as pd
import seaborn as sns

# %% [markdown]
# ## Reading file

# %%
df = pd.read_csv("C:/My data/udemy/Data/House_Price.csv")

# %%
df.head()
# Out:
#    price  crime_rate  resid_area  air_qual  room_num   age  dist1  dist2  \
# 0   24.0     0.00632       32.31     0.538     6.575  65.2   4.35   3.81
# 1   21.6     0.02731       37.07     0.469     6.421  78.9   4.99   4.70
# 2   34.7     0.02729       37.07     0.469     7.185  61.1   5.03   4.86
# 3   33.4     0.03237       32.18     0.458     6.998  45.8   6.21   5.93
# 4   36.2     0.06905       32.18     0.458     7.147  54.2   6.16   5.86
#
#    dist3  dist4  teachers  poor_prop airport  n_hos_beds  n_hot_rooms  \
# 0   4.18   4.01      24.7       4.98     YES       5.480      11.1920
# 1   5.12   5.06      22.2       9.14      NO       7.332      12.1728
# 2   5.01   4.97      22.2       4.03      NO       7.394     101.1200
# 3   6.16   5.96      21.3       2.94     YES       9.268      11.2672
# 4   6.37   5.86      21.3       5.33      NO       8.824      11.2896
#
#   waterbody  rainfall bus_ter     parks
# 0     River        23     YES  0.049347
# ...

# %% [markdown]
# #### due to .shape cammond we know how rows and coloumns in data

# %%
df.shape
# Out:
# (506, 19)

# %% [markdown]
# ### EDD(Extented Data Dictionary)

# %%
df.describe()
# Out:
#             price  crime_rate  resid_area    air_qual    room_num         age  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean    22.528854    3.613524   41.136779    0.554695    6.284634   68.574901
# std      9.182176    8.601545    6.860353    0.115878    0.702617   28.148861
# min      5.000000    0.006320   30.460000    0.385000    3.561000    2.900000
# 25%     17.025000    0.082045   35.190000    0.449000    5.885500   45.025000
# 50%     21.200000    0.256510   39.690000    0.538000    6.208500   77.500000
# 75%     25.000000    3.677082   48.100000    0.624000    6.623500   94.075000
# max     50.000000   88.976200   57.740000    0.871000    8.780000  100.000000
#
#             dist1       dist2       dist3       dist4    teachers   poor_prop  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean     3.971996    3.628775    3.960672    3.618972   21.544466   12.653063
# ...

# %% [markdown]
# ## seaborn.boxplot command

# %%
sns.boxplot(y='n_hot_rooms', data=df)

# %%
sns.boxplot(y='n_hos_beds', data=df)

# %% [markdown]
# ### seaborn .jointplot command

# %%
sns.jointplot(x = "n_hot_rooms", y = "price", data = df)

# %%
sns.jointplot(x ="n_hos_beds", y = "price", data = df)

# %%
sns.jointplot(x = "rainfall", y ="price",data=df)

# %%
df.head()
# Out:
#    price  crime_rate  resid_area  air_qual  room_num   age  dist1  dist2  \
# 0   24.0     0.00632       32.31     0.538     6.575  65.2   4.35   3.81
# 1   21.6     0.02731       37.07     0.469     6.421  78.9   4.99   4.70
# 2   34.7     0.02729       37.07     0.469     7.185  61.1   5.03   4.86
# 3   33.4     0.03237       32.18     0.458     6.998  45.8   6.21   5.93
# 4   36.2     0.06905       32.18     0.458     7.147  54.2   6.16   5.86
#
#    dist3  dist4  teachers  poor_prop airport  n_hos_beds  n_hot_rooms  \
# 0   4.18   4.01      24.7       4.98     YES       5.480      11.1920
# 1   5.12   5.06      22.2       9.14      NO       7.332      12.1728
# 2   5.01   4.97      22.2       4.03      NO       7.394     101.1200
# 3   6.16   5.96      21.3       2.94     YES       9.268      11.2672
# 4   6.37   5.86      21.3       5.33      NO       8.824      11.2896
#
#   waterbody  rainfall bus_ter     parks
# 0     River        23     YES  0.049347
# ...

# %% [markdown]
# ### seaborn countplot cammand

# %%
sns.countplot(x = "airport",data=df)

# %%
sns.countplot(x = "waterbody",data=df)

# %%
sns.countplot(x="bus_ter",data=df)

# %% [markdown]
# ## observation
# 1.missing values in n_hos_beds
# 2.outliers in crime_rate and n_hot_rooms
# 3.bus_ter is contain only one "Yes" value

# %% [markdown]
# ## Outliers

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 506 entries, 0 to 505
# Data columns (total 19 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   price        506 non-null    float64
#  1   crime_rate   506 non-null    float64
#  2   resid_area   506 non-null    float64
#  3   air_qual     506 non-null    float64
#  4   room_num     506 non-null    float64
#  5   age          506 non-null    float64
#  6   dist1        506 non-null    float64
#  7   dist2        506 non-null    float64
#  8   dist3        506 non-null    float64
#  9   dist4        506 non-null    float64
#  10  teachers     506 non-null    float64
#  11  poor_prop    506 non-null    float64
#  12  airport      506 non-null    object
#  13  n_hos_beds   498 non-null    float64
#  14  n_hot_rooms  506 non-null    float64
#  15  waterbody    506 non-null    object
#  16  rainfall     506 non-null    int64
#  17  bus_ter      506 non-null    object
# ...

# %% [markdown]
# #### np.percentile cammond

# %%
np.percentile(df.n_hot_rooms,[99])
# Out:
# array([15.39952])

# %%
np.percentile(df.n_hot_rooms,[99])[0]
# Out:
# 15.399519999999999

# %%
uv = np.percentile(df.n_hot_rooms,[99])[0]

# %%
df[(df.n_hot_rooms > uv)]
# Out:
#         price  crime_rate  resid_area  air_qual  room_num       age     dist1  \
# 2    46.19856    46.19856    46.19856  46.19856  46.19856  46.19856  46.19856
# 166  50.00000     2.01019    49.58000   0.60500   7.92900  96.20000   2.11000
# 204  50.00000     0.02009    32.68000   0.41610   8.03400  31.90000   5.41000
# 267  50.00000     0.57834    33.97000   0.57500   8.29700  67.00000   2.60000
# 369  50.00000     5.66998    48.10000   0.63100   6.68300  96.80000   1.55000
# 423  46.19856    46.19856    46.19856  46.19856  46.19856  46.19856  46.19856
#
#         dist2     dist3     dist4  teachers  poor_prop  airport  n_hos_beds  \
# 2    46.19856  46.19856  46.19856  46.19856   46.19856  46.1986    46.19856
# 166   1.91000   2.31000   1.86000  25.30000    3.70000      YES     8.30000
# 204   4.80000   5.28000   4.99000  25.30000    2.88000      YES     8.90000
# 267   2.13000   2.43000   2.52000  27.00000    7.44000      YES     8.00000
# ...

# %%
df.n_hot_rooms[(df.n_hot_rooms >3*uv)] = 3*uv
# Out:
# <ipython-input-51-61dd286b51a3>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.n_hot_rooms[(df.n_hot_rooms >3*uv)] = 3*uv

# %%
np.percentile(df.rainfall,[1])[0]
# Out:
# 20.0

# %%
lv = np.percentile(df.rainfall,[1])[0]

# %%
df[(df.rainfall < lv)]
# Out:
#      price  crime_rate  resid_area  air_qual  room_num   age  dist1  dist2  \
# 213   28.1     0.14052       40.59     0.489     6.375  32.3   4.11   3.92
#
#      dist3  dist4  teachers  poor_prop airport  n_hos_beds  n_hot_rooms  \
# 213   4.18   3.57      21.4       9.38     YES       7.562      10.2248
#
#     waterbody  rainfall bus_ter     parks
# 213      None       6.0     YES  0.044019

# %%
df.rainfall[(df.rainfall < 0.3* lv)] = 0.3*lv
# Out:
# <ipython-input-56-633c5fd7f9f1>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.rainfall[(df.rainfall < 0.3* lv)] = 0.3*lv

# %%
sns.jointplot(x="crime_rate", y="price",data=df)

# %%
df.describe()
# Out:
#             price  crime_rate  resid_area    air_qual    room_num         age  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean    22.616397    3.782139   41.151062    0.735158    6.440977   68.468571
# std      9.277130    9.005074    6.858349    2.869097    2.603248   28.172303
# min      5.000000    0.006320   30.460000    0.385000    3.561000    2.900000
# 25%     17.100000    0.082268   35.190000    0.449000    5.885500   45.025000
# 50%     21.200000    0.260420   39.690000    0.538000    6.209000   77.150000
# 75%     25.000000    3.689387   48.100000    0.624000    6.628000   94.075000
# max     50.000000   88.976200   57.740000   46.198560   46.198560  100.000000
#
#             dist1       dist2       dist3       dist4    teachers   poor_prop  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean     4.140548    3.798216    4.128749    3.788058   21.644065   12.781674
# ...

# %% [markdown]
# ### missing value

# %% [markdown]
# #### for Numarical variables, impute missing value with mean and median
# #### for categorical variables, impute missing value with mode

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 506 entries, 0 to 505
# Data columns (total 19 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   price        506 non-null    float64
#  1   crime_rate   506 non-null    float64
#  2   resid_area   506 non-null    float64
#  3   air_qual     506 non-null    float64
#  4   room_num     506 non-null    float64
#  5   age          506 non-null    float64
#  6   dist1        506 non-null    float64
#  7   dist2        506 non-null    float64
#  8   dist3        506 non-null    float64
#  9   dist4        506 non-null    float64
#  10  teachers     506 non-null    float64
#  11  poor_prop    506 non-null    float64
#  12  airport      506 non-null    object
#  13  n_hos_beds   506 non-null    float64
#  14  n_hot_rooms  506 non-null    float64
#  15  waterbody    506 non-null    object
#  16  rainfall     506 non-null    float64
#  17  bus_ter      506 non-null    object
# ...

# %%
df.n_hos_beds=df.n_hos_beds.fillna(df.n_hos_beds.mean())

# %%
sns.jointplot(x="crime_rate", y="price",data=df)

# %% [markdown]
# ## Transformation

# %%
df.crime_rate = np.log(1+df.crime_rate)

# %%
sns.jointplot(x="crime_rate", y="price",data=df)

# %%
df.describe()
# Out:
#             price  crime_rate  resid_area    air_qual    room_num         age  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean    22.616397    0.824478   41.151062    0.735158    6.440977   68.468571
# std      9.277130    1.038292    6.858349    2.869097    2.603248   28.172303
# min      5.000000    0.006300   30.460000    0.385000    3.561000    2.900000
# 25%     17.100000    0.079058   35.190000    0.449000    5.885500   45.025000
# 50%     21.200000    0.231444   39.690000    0.538000    6.209000   77.150000
# 75%     25.000000    1.545301   48.100000    0.624000    6.628000   94.075000
# max     50.000000    4.499545   57.740000   46.198560   46.198560  100.000000
#
#             dist1       dist2       dist3       dist4    teachers   poor_prop  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean     4.140548    3.798216    4.128749    3.788058   21.644065   12.781674
# ...

# %%
df["avg_dist"] = (df.dist1+df.dist2+df.dist3+df.dist4)/4

# %%
df.head()
# Out:
#       price  crime_rate  resid_area  air_qual  room_num       age     dist1  \
# 0  24.00000    0.006300    32.31000   0.53800   6.57500  65.20000   4.35000
# 1  21.60000    0.026944    37.07000   0.46900   6.42100  78.90000   4.99000
# 2  46.19856    3.854363    46.19856  46.19856  46.19856  46.19856  46.19856
# 3  33.40000    0.031857    32.18000   0.45800   6.99800  45.80000   6.21000
# 4  36.20000    0.066770    32.18000   0.45800   7.14700  54.20000   6.16000
#
#       dist2     dist3     dist4  teachers  poor_prop  airport  n_hos_beds  \
# 0   3.81000   4.18000   4.01000  24.70000    4.98000      YES     5.48000
# 1   4.70000   5.12000   5.06000  22.20000    9.14000       NO     7.33200
# 2  46.19856  46.19856  46.19856  46.19856   46.19856  46.1986    46.19856
# 3   5.93000   6.16000   5.96000  21.30000    2.94000      YES     9.26800
# 4   5.86000   6.37000   5.86000  21.30000    5.33000       NO     8.82400
#
# ...

# %% [markdown]
# ### for delete the column use || del data name ["column name"] ||

# %%
del df["dist1"]

# %%
df.head()
# Out:
#       price  crime_rate  resid_area  air_qual  room_num       age     dist2  \
# 0  24.00000    0.006300    32.31000   0.53800   6.57500  65.20000   3.81000
# 1  21.60000    0.026944    37.07000   0.46900   6.42100  78.90000   4.70000
# 2  46.19856    3.854363    46.19856  46.19856  46.19856  46.19856  46.19856
# 3  33.40000    0.031857    32.18000   0.45800   6.99800  45.80000   5.93000
# 4  36.20000    0.066770    32.18000   0.45800   7.14700  54.20000   5.86000
#
#       dist3     dist4  teachers  poor_prop  airport  n_hos_beds  n_hot_rooms  \
# 0   4.18000   4.01000  24.70000    4.98000      YES     5.48000     11.19200
# 1   5.12000   5.06000  22.20000    9.14000       NO     7.33200     12.17280
# 2  46.19856  46.19856  46.19856   46.19856  46.1986    46.19856     46.19856
# 3   6.16000   5.96000  21.30000    2.94000      YES     9.26800     11.26720
# 4   6.37000   5.86000  21.30000    5.33000       NO     8.82400     11.28960
#
# ...

# %%
del df["dist2"]

# %%
del df["dist3"]

# %%
del df["dist4"]

# %%
del df["bus_ter"]

# %%
df.head()
# Out:
#       price  crime_rate  resid_area  air_qual  room_num       age  teachers  \
# 0  24.00000    0.006300    32.31000   0.53800   6.57500  65.20000  24.70000
# 1  21.60000    0.026944    37.07000   0.46900   6.42100  78.90000  22.20000
# 2  46.19856    3.854363    46.19856  46.19856  46.19856  46.19856  46.19856
# 3  33.40000    0.031857    32.18000   0.45800   6.99800  45.80000  21.30000
# 4  36.20000    0.066770    32.18000   0.45800   7.14700  54.20000  21.30000
#
#    poor_prop  airport  n_hos_beds  n_hot_rooms waterbody  rainfall      parks  \
# 0    4.98000      YES     5.48000     11.19200     River  23.00000   0.049347
# 1    9.14000       NO     7.33200     12.17280      Lake  42.00000   0.046146
# 2   46.19856  46.1986    46.19856     46.19856   46.1986  46.19856  46.198560
# 3    2.94000      YES     9.26800     11.26720      Lake  45.00000   0.047151
# 4    5.33000       NO     8.82400     11.28960      Lake  55.00000   0.039474
#
#    avg_dist
# 0   4.08750
# 1   4.96750
# ...

# %% [markdown]
# ### creationg Dummy variables by using ||  pd.get_dammies(data) ||

# %%
df = pd.get_dummies(df)

# %%
df.head()
# Out:
#       price  crime_rate  resid_area  air_qual  room_num       age  teachers  \
# 0  24.00000    0.006300    32.31000   0.53800   6.57500  65.20000  24.70000
# 1  21.60000    0.026944    37.07000   0.46900   6.42100  78.90000  22.20000
# 2  46.19856    3.854363    46.19856  46.19856  46.19856  46.19856  46.19856
# 3  33.40000    0.031857    32.18000   0.45800   6.99800  45.80000  21.30000
# 4  36.20000    0.066770    32.18000   0.45800   7.14700  54.20000  21.30000
#
#    poor_prop  n_hos_beds  n_hot_rooms  ...      parks  avg_dist  \
# 0    4.98000     5.48000     11.19200  ...   0.049347   4.08750
# 1    9.14000     7.33200     12.17280  ...   0.046146   4.96750
# 2   46.19856    46.19856     46.19856  ...  46.198560  46.19856
# 3    2.94000     9.26800     11.26720  ...   0.047151   6.06500
# 4    5.33000     8.82400     11.28960  ...   0.039474   6.06250
#
#    airport_46.19856  airport_NO  airport_YES  waterbody_46.19856  \
# ...

# %%
del df['airport_46.19856']

# %%
del df['waterbody_46.19856']

# %%
df.head()
# Out:
#       price  crime_rate  resid_area  air_qual  room_num       age  teachers  \
# 0  24.00000    0.006300    32.31000   0.53800   6.57500  65.20000  24.70000
# 1  21.60000    0.026944    37.07000   0.46900   6.42100  78.90000  22.20000
# 2  46.19856    3.854363    46.19856  46.19856  46.19856  46.19856  46.19856
# 3  33.40000    0.031857    32.18000   0.45800   6.99800  45.80000  21.30000
# 4  36.20000    0.066770    32.18000   0.45800   7.14700  54.20000  21.30000
#
#    poor_prop  n_hos_beds  n_hot_rooms  rainfall      parks  avg_dist  \
# 0    4.98000     5.48000     11.19200  23.00000   0.049347   4.08750
# 1    9.14000     7.33200     12.17280  42.00000   0.046146   4.96750
# 2   46.19856    46.19856     46.19856  46.19856  46.198560  46.19856
# 3    2.94000     9.26800     11.26720  45.00000   0.047151   6.06500
# 4    5.33000     8.82400     11.28960  55.00000   0.039474   6.06250
#
#    airport_NO  airport_YES  waterbody_Lake  waterbody_Lake and River  \
# ...

# %%
del df['waterbody_Lake and River']

# %%
del df['waterbody_None']

# %%
df.head()
# Out:
#       price  crime_rate  resid_area  air_qual  room_num       age  teachers  \
# 0  24.00000    0.006300    32.31000   0.53800   6.57500  65.20000  24.70000
# 1  21.60000    0.026944    37.07000   0.46900   6.42100  78.90000  22.20000
# 2  46.19856    3.854363    46.19856  46.19856  46.19856  46.19856  46.19856
# 3  33.40000    0.031857    32.18000   0.45800   6.99800  45.80000  21.30000
# 4  36.20000    0.066770    32.18000   0.45800   7.14700  54.20000  21.30000
#
#    poor_prop  n_hos_beds  n_hot_rooms  rainfall      parks  avg_dist  \
# 0    4.98000     5.48000     11.19200  23.00000   0.049347   4.08750
# 1    9.14000     7.33200     12.17280  42.00000   0.046146   4.96750
# 2   46.19856    46.19856     46.19856  46.19856  46.198560  46.19856
# 3    2.94000     9.26800     11.26720  45.00000   0.047151   6.06500
# 4    5.33000     8.82400     11.28960  55.00000   0.039474   6.06250
#
#    airport_NO  airport_YES  waterbody_Lake  waterbody_River
# ...

# %% [markdown]
# ### correlation between two columns by using || df.corr() ||

# %%
df.corr()
# Out:
#                     price  crime_rate  resid_area  air_qual  room_num  \
# price            1.000000   -0.420983   -0.468976  0.143113  0.339334
# crime_rate      -0.420983    1.000000    0.655763  0.211913  0.101115
# resid_area      -0.468976    0.655763    1.000000  0.077144 -0.060507
# air_qual         0.143113    0.211913    0.077144  1.000000  0.958961
# room_num         0.339334    0.101115   -0.060507  0.958961  1.000000
# age             -0.379976    0.539752    0.640626 -0.020327 -0.112533
# teachers         0.498653   -0.203608   -0.283355  0.575358  0.638300
# poor_prop       -0.654315    0.624286    0.590164  0.306571  0.115027
# n_hos_beds       0.193389    0.154680    0.042261  0.852347  0.827075
# n_hot_rooms      0.134055    0.188038    0.022108  0.781633  0.749970
# rainfall        -0.042430    0.089224    0.059024  0.038836  0.016309
# parks            0.158878    0.186304    0.048994  0.999314  0.962732
# ...

# %%
del df['parks']

# %%
df.head()
# Out:
#       price  crime_rate  resid_area  air_qual  room_num       age  teachers  \
# 0  24.00000    0.006300    32.31000   0.53800   6.57500  65.20000  24.70000
# 1  21.60000    0.026944    37.07000   0.46900   6.42100  78.90000  22.20000
# 2  46.19856    3.854363    46.19856  46.19856  46.19856  46.19856  46.19856
# 3  33.40000    0.031857    32.18000   0.45800   6.99800  45.80000  21.30000
# 4  36.20000    0.066770    32.18000   0.45800   7.14700  54.20000  21.30000
#
#    poor_prop  n_hos_beds  n_hot_rooms  rainfall  avg_dist  airport_NO  \
# 0    4.98000     5.48000     11.19200  23.00000   4.08750           0
# 1    9.14000     7.33200     12.17280  42.00000   4.96750           1
# 2   46.19856    46.19856     46.19856  46.19856  46.19856           0
# 3    2.94000     9.26800     11.26720  45.00000   6.06500           0
# 4    5.33000     8.82400     11.28960  55.00000   6.06250           1
#
#    airport_YES  waterbody_Lake  waterbody_River
# ...

# %% [markdown]
# ### LinearRegression method 1

# %%
import statsmodels.api as sn

# %%
x = sn.add_constant(df['room_num'])

# %%
lm = sn.OLS(df['price'],x).fit

# %% [markdown]
# ### LinearRegression model method 2

# %%
from sklearn.linear_model import LinearRegression

# %%
y = df['price']

# %%
x = df[['room_num']]

# %%
lm2 = LinearRegression()

# %%
lm2.fit(x,y)
# Out:
# LinearRegression()

# %%
print(lm2.intercept_, lm2.coef_)
# Out:
# 14.82749006653546 [1.2092743]

# %%
help(lm2)
# Out:
# Help on LinearRegression in module sklearn.linear_model._base object:
#
# class LinearRegression(sklearn.base.MultiOutputMixin, sklearn.base.RegressorMixin, LinearModel)
#  |  LinearRegression(*, fit_intercept=True, normalize=False, copy_X=True, n_jobs=None)
#  |
#  |  Ordinary least squares Linear Regression.
#  |
#  |  LinearRegression fits a linear model with coefficients w = (w1, ..., wp)
#  |  to minimize the residual sum of squares between the observed targets in
#  |  the dataset, and the targets predicted by the linear approximation.
#  |
#  |  Parameters
#  |  ----------
#  |  fit_intercept : bool, default=True
#  |      Whether to calculate the intercept for this model. If set
#  |      to False, no intercept will be used in calculations
#  |      (i.e. data is expected to be centered).
#  |
#  |  normalize : bool, default=False
#  |      This parameter is ignored when ``fit_intercept`` is set to False.
# ...

# %%
lm2.predict(x)
# Out:
# array([22.77846862, 22.59224038, 70.69422158, 23.28999165, 23.47017352,
#        22.60312384, 22.09764719, 22.29113107, 21.63691368, 22.08797299,
#        22.53903231, 22.09401936, 21.94890645, 22.0214629 , 22.19922623,
#        21.88239636, 22.00453306, 22.07104315, 21.42529067, 21.75300401,
#        21.56314794, 22.04081129, 22.25485284, 21.8570016 , 21.99123105,
#        21.5982169 , 21.8570016 , 22.13997179, 22.68172667, 22.89818677,
#        21.73607417, 22.17020364, 22.02267218, 21.72156288, 22.19922623,
#        22.00211452, 21.89086128, 21.90174475, 22.04202057, 22.8026541 ,
#        23.32143278, 23.01427711, 22.28750325, 22.33829277, 22.16657582,
#        21.69858666, 21.82435119, 22.11941412, 21.35636204, 21.60184472,
#        22.03839274, 22.22220244, 22.70107506, 22.08071735, 21.94769717,
#        23.5935195 , 22.54628795, 23.06990373, 22.25848067, 21.99485887,
#        21.76993385, 22.04202057, 22.63456498, 23.00460291, 23.41817473,
# ...

# %%
help(sns.jointplot)
# Out:
# Help on function jointplot in module seaborn.axisgrid:
#
# jointplot(x, y, data=None, kind='scatter', stat_func=None, color=None, height=6, ratio=5, space=0.2, dropna=True, xlim=None, ylim=None, joint_kws=None, marginal_kws=None, annot_kws=None, **kwargs)
#     Draw a plot of two variables with bivariate and univariate graphs.
#
#     This function provides a convenient interface to the :class:`JointGrid`
#     class, with several canned plot kinds. This is intended to be a fairly
#     lightweight wrapper; if you need more flexibility, you should use
#     :class:`JointGrid` directly.
#
#     Parameters
#     ----------
#     x, y : strings or vectors
#         Data or names of variables in ``data``.
#     data : DataFrame, optional
#         DataFrame when ``x`` and ``y`` are variable names.
#     kind : { "scatter" | "reg" | "resid" | "kde" | "hex" }, optional
#         Kind of plot to draw.
#     stat_func : callable or None, optional
#         *Deprecated*
# ...

# %%
sns.jointplot(x=df['room_num'], y=df['price'], data=df, kind='reg')

# %% [markdown]
# ### checking accuracy of model

# %%
x,y
lm2.score(x,y)*100
# Out:
# 11.514722659355048

# %% [markdown]
# # Multi Regreassion Model

# %%
x_multi = df.drop('price', axis=1)

# %%
x_multi.head()
# Out:
#    crime_rate  resid_area  air_qual  room_num       age  teachers  poor_prop  \
# 0    0.006300    32.31000   0.53800   6.57500  65.20000  24.70000    4.98000
# 1    0.026944    37.07000   0.46900   6.42100  78.90000  22.20000    9.14000
# 2    3.854363    46.19856  46.19856  46.19856  46.19856  46.19856   46.19856
# 3    0.031857    32.18000   0.45800   6.99800  45.80000  21.30000    2.94000
# 4    0.066770    32.18000   0.45800   7.14700  54.20000  21.30000    5.33000
#
#    n_hos_beds  n_hot_rooms  rainfall  avg_dist  airport_NO  airport_YES  \
# 0     5.48000     11.19200  23.00000   4.08750           0            1
# 1     7.33200     12.17280  42.00000   4.96750           1            0
# 2    46.19856     46.19856  46.19856  46.19856           0            0
# 3     9.26800     11.26720  45.00000   6.06500           0            1
# 4     8.82400     11.28960  55.00000   6.06250           1            0
#
#    waterbody_Lake  waterbody_River
# ...

# %%
y_multi = df['price']

# %%
y_multi.head()
# Out:
# 0    24.00000
# 1    21.60000
# 2    46.19856
# 3    33.40000
# 4    36.20000
# Name: price, dtype: float64

# %%
x_multi_cons = sn.add_constant(x_multi)

# %%
x_multi_cons.head()
# Out:
#    const  crime_rate  resid_area  air_qual  room_num       age  teachers  \
# 0    1.0    0.006300    32.31000   0.53800   6.57500  65.20000  24.70000
# 1    1.0    0.026944    37.07000   0.46900   6.42100  78.90000  22.20000
# 2    1.0    3.854363    46.19856  46.19856  46.19856  46.19856  46.19856
# 3    1.0    0.031857    32.18000   0.45800   6.99800  45.80000  21.30000
# 4    1.0    0.066770    32.18000   0.45800   7.14700  54.20000  21.30000
#
#    poor_prop  n_hos_beds  n_hot_rooms  rainfall  avg_dist  airport_NO  \
# 0    4.98000     5.48000     11.19200  23.00000   4.08750           0
# 1    9.14000     7.33200     12.17280  42.00000   4.96750           1
# 2   46.19856    46.19856     46.19856  46.19856  46.19856           0
# 3    2.94000     9.26800     11.26720  45.00000   6.06500           0
# 4    5.33000     8.82400     11.28960  55.00000   6.06250           1
#
#    airport_YES  waterbody_Lake  waterbody_River
# 0            1               0                1
# ...

# %%
lm_multi = sn.OLS(y_multi, x_multi_cons).fit

# %%
lm_multi.summary()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-151-1f1b6e1ca557> in <module>
# ----> 1 lm_multi.summary()
#
# AttributeError: 'function' object has no attribute 'summary'

# %%
lm3 =LinearRegression()

# %%
lm3.fit(x_multi,y_multi)
# Out:
# LinearRegression()

# %%
print(lm3.intercept_, lm3.coef_)
# Out:
# 613.0347584497466 [ 8.01439563e-03 -3.83957481e-02 -1.59875055e+01  4.02280834e+00
#  -5.13936641e-03  1.00802772e+00 -5.74806697e-01  3.25248204e-01
#   1.77975594e-01  1.32348081e-02 -1.21168021e+00 -6.20909977e+02
#  -6.19770186e+02  5.30599949e-01 -5.53727665e-02]

# %% [markdown]
# ## Test_Train_split

# %% [raw]
# from sklearn.model_selection import train_test_split

# %%
x_train, x_test, y_train, y_test = train_test_split(x_multi, y_multi, test_size=0.2, random_state=0)

# %%
print(x_train.shape, x_test.shape, y_train.shape, y_test.shape)
# Out:
# (404, 15) (102, 15) (404,) (102,)

# %%
lm_a = LinearRegression()

# %%
lm_a.fit(x_train, y_train)
# Out:
# LinearRegression()

# %%
y_test_a = lm_a.predict(x_test)

# %%
y_train_a=lm_a.predict(x_train)

# %%
from sklearn.metrics import r2_score

# %%
r2_score(y_test,y_test_a)
# Out:
# 0.5490176244593638

# %%
r2_score(y_train, y_train_a)
# Out:
# 0.762812477517563
